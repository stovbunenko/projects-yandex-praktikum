# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра" data-toc-modified-id="Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?" data-toc-modified-id="Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили" data-toc-modified-id="Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года" data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-среди-них-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-'locality_name'." data-toc-modified-id="Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-среди-них-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-'locality_name'.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце 'locality_name'.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-('locality_name').-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется-—-это-и-будет-центральная-зона." data-toc-modified-id="Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-('locality_name').-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется-—-это-и-будет-центральная-зона.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?" data-toc-modified-id="Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Описание данных**
#
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах(м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении
#
# Пояснение: апартаменты — это нежилые помещения, не относящиеся к жилому фонду, но имеющие необходимые условия для проживания.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import numpy as np
import pprint
import matplotlib.pyplot as plt
import seaborn as sn

from pymystem3 import Mystem
from collections import Counter

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
df.tail()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 23694             3.7           5.0         73.3      3          NaN   False
# 23695             NaN           5.0         38.0      4          NaN   False
# 23696             NaN           3.0         29.7      1          NaN   False
# 23697             3.0          17.0          NaN     12          NaN   False
# 23698             2.5           5.0         12.3      1          NaN   False
#
#        open_plan  kitchen_area  balcony        locality_name  \
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# Посмотрим какая доля пропусков:
# (можно сразу прикинуть % даже не умножая на 100)

# %%
df.isna().mean()
# Out:
# total_images           0.000
# last_price             0.000
# total_area             0.000
# first_day_exposition   0.000
# rooms                  0.000
# ceiling_height         0.388
# floors_total           0.004
# living_area            0.080
# floor                  0.000
# is_apartment           0.883
# studio                 0.000
# open_plan              0.000
# kitchen_area           0.096
# balcony                0.486
# locality_name          0.002
# airports_nearest       0.234
# cityCenters_nearest    0.233
# parks_around3000       0.233
# parks_nearest          0.659
# ponds_around3000       0.233
# ponds_nearest          0.616
# days_exposition        0.134
# dtype: float64

# %% [markdown]
# - парков в Санкт-Петербурге всего 68, поэтому очевидно, что не на всех жителей их хватает. Оставим значения nan
# - ceiling_height - посмотреть значения по describe(), сгруппировать похожие предложения и заполнить пропуски "подобными" значениями
# - расстояния до ближайших водоемов (ponds_nearest) так же предварительно оставим nan, к тому же этот массив данных получен автоматически, значит, система сбора данных не нашла подходящих значений

# %%
df.describe()
# Out:
#        total_images    last_price  total_area     rooms  ceiling_height  \
# count     23699.000     23699.000   23699.000 23699.000       14504.000
# mean          9.858   6541548.772      60.349     2.071           2.771
# std           5.683  10887013.268      35.654     1.078           1.261
# min           0.000     12190.000      12.000     0.000           1.000
# 25%           6.000   3400000.000      40.000     1.000           2.520
# 50%           9.000   4650000.000      52.000     2.000           2.650
# 75%          14.000   6800000.000      69.900     3.000           2.800
# max          50.000 763000000.000     900.000    19.000         100.000
#
#        floors_total  living_area     floor  kitchen_area   balcony  \
# count     23613.000    21796.000 23699.000     21421.000 12180.000
# mean         10.674       34.458     5.892        10.570     1.150
# std           6.597       22.030     4.885         5.905     1.071
# ...

# %% [markdown]
# - Минимальное значение цены в 12190 - неправдопадобно мало
# - Высота потолка в 1 и 100 метров - очень странно!
# - Бывает ли в доме только один этаж - да, 60 - вряд ли. На данный момент самое высокое здание пока в Санкт-Петербурге в 42 этажа
# - Жилая площадь в 2 квадратных метра - очень мало!
# - Минимальная площадь кухни в 1,3 квадрата - странно!
# - Значение в 0 км до аэропорта. Кто-то живет прямо в аэропорту? Надо будет исправить и посмотреть общее количество таких значений.
# - С парками и водоемами все, на первый взгляд, нормально.
# - Количество комнат 0 - это либо квартира-студия, либо ошибка. Надо проверить
# - Расстояния в м лучше перевести в км для удобства восприятия информации

# %% [markdown]
# ### Вывод

# %% [markdown]
# В датасете всего 23699 строки и 22 столбца. Много пропусков значений в столбцах ceiling_height, is_apartment, balcony, parks_nearest, ponds_nearest.
#
# **Проблемы, которые необходимо решить:**
# - first_day_exposition - должен быть тип datetime
# - is_apartment - должен быть тип bool. Больше 80% - nan, возможно, заполнить False, проверить рынок апартов на текущий момент
# - Разобраться с пропусками в столбцах, решить в каких случаях можно предположить логичную замену, а в каких правильно оставить эти значения пустыми
# - ceiling_height - посмотреть значения по describe(), сгруппировать похожие предложения и заполнить пропуски "подобными" значениями
# - Бросаются в глаза "некрасивые" названия: cityCenters_nearest , parks_around3000 и ponds_around3000. Заменим их в следующем шаге
# - расстояния до ближайших водоемов (ponds_nearest) так же предварительно оставим nan, к тому же этот массив данных получен автоматически, значит, система сбора данных не нашла подходящих значений
# - Минимальное значение цены в 12190
# - Высота потолка в 1 и 100 метров
# - На данный момент самое высокое здание пока в Санкт-Петербурге в 42 этажа. Странно, что в данных 60 этажей
# - Жилая площадь в 2 квадратных метра
# - Минимальная площадь кухни в 1,3 квадрата
# - Значение в 0 км до аэропорта. Надо исправить и посмотреть общее количество таких значений.
# - С парками и водоемами все, на первый взгляд, нормально.
#
# **В значения int нужно будет перевести следующие столбцы:**
#
# - last_price - ни разу не встречались обьявления о продаже квартир с копейками.
# - floors_total - целое число
# - floor - целое число
# - balcony - балкон всегда "целый"
# - airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest - значения в метрах, сантиметры не в счет
# - days_exposition - дни в "целом виде" будет считать удобнее

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Подсчитаем суммарное количество пропусков:

# %%
df.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Изменим названия cityCenters_nearest, parks_around3000, ponds_around3000
# на, соответственно:
# city_сenter_nearest, parks_around_3000, ponds_around_3000

# %%
df = df.rename(columns={'cityCenters_nearest': 'city_center_nearest', 'parks_around3000': 'parks_around_3000', 'ponds_around3000': 'ponds_around_3000'})
df.head()
# Out:
#    total_images   last_price  total_area first_day_exposition  rooms  \
# 0            20 13000000.000     108.000  2019-03-07T00:00:00      3
# 1             7  3350000.000      40.400  2018-12-04T00:00:00      1
# 2            10  5196000.000      56.000  2015-08-20T00:00:00      2
# 3             0 64900000.000     159.000  2015-07-24T00:00:00      3
# 4             2 10000000.000     100.000  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0           2.700        16.000       51.000      8          NaN   False
# 1             nan        11.000       18.600      1          NaN   False
# 2             nan         5.000       34.300      4          NaN   False
# 3             nan        14.000          nan      9          NaN   False
# 4           3.030        14.000       32.000     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Отбросим данные с незначительным кол-вом пропусков: locality_name, floors_total:

# %%
df = df.dropna(subset=['locality_name','floors_total'])

# %% [markdown]
# Переведем столбец с датой в формат даты без времени, т.к. время не указано:

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format = '%Y-%m-%d')

# %%
df['is_apartment'].unique()
# Out:
# array([nan, False, True], dtype=object)

# %% [markdown]
# Значения nan, False и True. Заменим nan на False:

# %%
df['is_apartment'].fillna(False).astype(bool) 
df['is_apartment'].isnull().sum()
# Out:
# 20805

# %% [markdown]
# Проверим количество комнат: (либо квартира-студия, либо ошибка).
# Проверим 1 вариант:

# %%
zero_flats_df = df.query('rooms == 0')

# %%
zero_flats_df['studio']
# Out:
# 144       True
# 349      False
# 440       True
# 508      False
# 608       True
#          ...
# 23210     True
# 23442    False
# 23554     True
# 23592    False
# 23637     True
# Name: studio, Length: 194, dtype: bool

# %% [markdown]
# Не все квартиры с 0 комнат - студии. Возможно, это просто маленькие квартиры?

# %%
zero_flats_df['total_area'].unique()
# Out:
# array([ 27.  ,  25.  ,  27.11,  34.4 ,  24.1 ,  17.  ,  26.1 ,  35.  ,
#         23.  ,  29.  ,  32.  ,  26.  ,  31.  ,  22.  ,  30.  ,  23.98,
#         27.55,  27.1 ,  28.4 ,  26.49,  28.9 ,  24.  ,  73.6 ,  21.4 ,
#         29.3 ,  28.  ,  20.  ,  19.5 ,  27.81,  26.8 ,  32.3 ,  42.63,
#         29.2 ,  27.3 ,  21.3 ,  19.  ,  18.8 ,  15.5 ,  38.3 ,  16.  ,
#         23.4 ,  27.56,  24.8 ,  28.3 ,  23.7 ,  44.2 ,  24.75,  20.5 ,
#         29.1 ,  26.7 ,  25.27,  27.32,  23.06,  23.5 ,  32.4 ,  21.  ,
#         24.2 ,  18.  ,  24.9 ,  58.4 ,  28.2 ,  24.05,  24.4 ,  25.2 ,
#         43.3 ,  27.4 ,  23.3 ,  32.2 ,  32.03,  25.7 ,  42.1 ,  22.3 ,
#         28.01,  32.8 ,  26.23,  25.3 ,  28.05,  31.1 ,  22.5 ,  25.9 ,
#         32.5 ,  23.8 , 371.  ,  24.6 ,  30.5 ,  25.41,  98.4 ,  23.6 ,
#         22.2 ,  27.5 ,  28.16,  27.6 ,  71.  ,  28.5 ,  24.5 ,  22.7 ,
#         34.  ,  30.1 ,  27.7 ,  26.05,  23.39])

# %% [markdown]
# Да, это просто очень маленькие квартиры.

# %%
df.query('rooms == 0 and studio==False')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 349               4  2320000.000      25.000           2017-09-27      0
# 508               0  3375000.000      34.400           2017-03-28      0
# 780               9  2600000.000      26.100           2018-02-20      0
# 839              14  1900000.000      35.000           2017-04-14      0
# 946               5  2200000.000      23.000           2016-09-27      0
# 1574              0  2200000.000      22.000           2017-11-03      0
# 1625              7  1980000.000      23.980           2018-02-01      0
# 2532              5  3500000.000      27.100           2018-02-01      0
# 3019             18  2100000.000      24.000           2017-11-10      0
# 4115              7  2600000.000      24.000           2018-02-01      0
# 4437             10  3200000.000      25.000           2017-10-16      0
# 4683              2  3650000.000      35.000           2018-02-01      0
# ...

# %% [markdown]
# У всех квартир где 0 комнат и не-студий указана living_area. Соответственно, хотя бы 1 комната там есть, поэтому поменяем 0 на 1(чтобы не путаться):

# %%
df.loc[(df['rooms'] == 0) & (df['studio']==False),'rooms'] = 1

# %% [markdown]
# Нулевых значений в living_area и kitchen_area нет, поэтому для удобства заменим Nan на 0. Заменим пропуски в balcony на 0 (скорее всего балконов в этих помещениях просто нет). Заменим пропуски в days_exposition:

# %%
df_columns = ['balcony', 'days_exposition', 'living_area', 'kitchen_area']
for i in df_columns:
    df[i] = df[i].fillna(0)

# %%
df.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9084
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment            20805
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5524
# city_center_nearest      5501
# parks_around_3000        5500
# parks_nearest           15535
# ponds_around_3000        5500
# ponds_nearest           14529
# days_exposition             0
# dtype: int64

# %%
df['kitchen_area'].describe()
# Out:
# count   23565.000
# mean        9.565
# std         6.408
# min         0.000
# 25%         6.300
# 50%         9.000
# 75%        11.410
# max       112.000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Минимальными значениями кухни сделаем 5 м2. Меньшая площадь запрещена по строительным и пожарным нормам:

# %%
df.loc[df['kitchen_area'] < 5, 'kitchen_area'] = 5

# %%
cols = ['floors_total', 'floor', 'balcony', 'last_price', 'days_exposition']
df[cols] = df[cols].astype(int)

# %%
df.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000     108.000           2019-03-07      3
# 1             7     3350000      40.400           2018-12-04      1
# 2            10     5196000      56.000           2015-08-20      2
# 3             0    64900000     159.000           2015-07-24      3
# 4             2    10000000     100.000           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0           2.700            16       51.000      8          NaN   False
# 1             nan            11       18.600      1          NaN   False
# 2             nan             5       34.300      4          NaN   False
# 3             nan            14        0.000      9          NaN   False
# 4           3.030            14       32.000     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Посмотрим оставшиеся пропуски:

# %%
df.isna().mean()
# Out:
# total_images           0.000
# last_price             0.000
# total_area             0.000
# first_day_exposition   0.000
# rooms                  0.000
# ceiling_height         0.385
# floors_total           0.000
# living_area            0.000
# floor                  0.000
# is_apartment           0.883
# studio                 0.000
# open_plan              0.000
# kitchen_area           0.000
# balcony                0.000
# locality_name          0.000
# airports_nearest       0.234
# city_center_nearest    0.233
# parks_around_3000      0.233
# parks_nearest          0.659
# ponds_around_3000      0.233
# ponds_nearest          0.617
# days_exposition        0.000
# dtype: float64

# %%
df['ceiling_height'].value_counts()
# Out:
# 2.500      3515
# 2.600      1645
# 2.700      1571
# 3.000      1108
# 2.800       988
#            ...
# 27.500        1
# 5.000         1
# 3.590         1
# 4.800         1
# 100.000       1
# Name: ceiling_height, Length: 183, dtype: int64

# %%
df['ceiling_height'].describe()
# Out:
# count   14481.000
# mean        2.771
# std         1.262
# min         1.000
# 25%         2.510
# 50%         2.650
# 75%         2.800
# max       100.000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Значения меньше 2,5 м необходимо будет исправить, т.к. высота потолков по СНИПу должна быть не менее данного значения.
# Но сначала уберем двузначные значения, которые возникли, скорее всего, из-за неправильного ввода данных: 25 вместо 2.5 м:

# %%
df.loc[df['ceiling_height'] > 9,'ceiling_height'] = df.loc[df['ceiling_height'] > 9,'ceiling_height']/ 10

# %% [markdown]
# Проверим количество объектов с потолками, не вписывающимся в стандарты:

# %%
len(df[df['ceiling_height'] < 2.5]['ceiling_height'])
# Out:
# 78

# %% [markdown]
# Всего 78 обьектов с высотой потолков менее 2,5 м. Можно спокойно заменить их на стандартные значения без потери качества исследования:

# %%
df.loc[df['ceiling_height'] < 2.5,'ceiling_height'] = 2.5

# %% [markdown]
# Проверим количество очень высоких потолков:

# %%
len(df.loc[df['ceiling_height'] > 5, 'ceiling_height'])
# Out:
# 12

# %% [markdown]
# Всего 12! Можно изменить на максимальное значение (5) и продолжить исследование:

# %%
df.loc[df['ceiling_height'] > 5, 'ceiling_height'] = 5

# %% [markdown]
# Посчитаем количество Nan в столбце с высотой потолков.

# %% [markdown]
# Средняя высота и медианна почти не отличаются. Для заполение пустых можно принять любую из них:

# %%
len(df.query('ceiling_height.isna()'))
# Out:
# 9084

# %%
df[df['locality_name'] == 'Санкт-Петербург']['ceiling_height'].isna().sum()
# Out:
# 5555

# %% [markdown]
# В Санкт-Петербурге не заполнили значение потолка в обьявлениях 5555 раз. В данном случае логично будет заполнить пропущенные значения медианой потолков по Санкт-Петерубургу:

# %%
sp_ceiling = df[df['locality_name']=='Санкт-Петербург']['ceiling_height'].median()
sp_ceiling
# Out:
# 2.7

# %%
df['ceiling_height'] = df['ceiling_height'].fillna(sp_ceiling)
df['ceiling_height'] = round(df['ceiling_height'],1)

# %% [markdown]
# Заполняем пропуски расстояния: группируем и находим среднее значение расстояния:

# %%
df['city_center_nearest'].fillna(df.groupby('locality_name')['city_center_nearest'].transform('mean'))
# Out:
# 0       16028.000
# 1       18603.000
# 2       13933.000
# 3        6800.000
# 4        8098.000
#            ...
# 23694    4232.000
# 23695         nan
# 23696         nan
# 23697   10364.000
# 23698         nan
# Name: city_center_nearest, Length: 23565, dtype: float64

# %%
df['airports_nearest'].fillna(df.groupby('locality_name')['airports_nearest'].transform('mean'))
# Out:
# 0       18863.000
# 1       12817.000
# 2       21741.000
# 3       28098.000
# 4       31856.000
#            ...
# 23694   24665.000
# 23695         nan
# 23696         nan
# 23697   39140.000
# 23698         nan
# Name: airports_nearest, Length: 23565, dtype: float64

# %%
df['airports_nearest'].isnull().sum()
# Out:
# 5524

# %%
df['city_center_nearest'].isnull().sum()
# Out:
# 5501

# %% [markdown]
# Оставшиеся пропуски заполняем просто по среднемму значению расстояния:

# %%
df['airports_nearest']=df['airports_nearest'].fillna(df['airports_nearest'].mean())

# %%
df['city_center_nearest']=df['city_center_nearest'].fillna(df['city_center_nearest'].mean())

# %%
df.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment            20805
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest            0
# city_center_nearest         0
# parks_around_3000        5500
# parks_nearest           15535
# ponds_around_3000        5500
# ponds_nearest           14529
# days_exposition             0
# dtype: int64

# %%
df['city_center_km'] = (df['city_center_nearest']/1000).astype(int)
df['airports_km'] = (df['airports_nearest']/1000).astype(int)

# %% [markdown]
# Оставим parks_nearest и ponds_nearest без изменений, чтобы не искажать результат, так как пропуски составляют больше 60%. А вот в колонках parks_around_3000 и ponds_around_3000 заменим пропуски на средние значения, так как это не сильно отразится на результате:

# %%
df['parks_around_3000']=df['parks_around_3000'].fillna(df['parks_around_3000'].mean()).astype(int)

# %%
df['ponds_around_3000']=df['ponds_around_3000'].fillna(df['ponds_around_3000'].mean()).astype(int)

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000     108.000           2019-03-07      3
# 1             7     3350000      40.400           2018-12-04      1
# 2            10     5196000      56.000           2015-08-20      2
# 3             0    64900000     159.000           2015-07-24      3
# 4             2    10000000     100.000           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0           2.700            16       51.000      8          NaN   False
# 1           2.700            11       18.600      1          NaN   False
# 2           2.700             5       34.300      4          NaN   False
# 3           2.700            14        0.000      9          NaN   False
# 4           3.000            14       32.000     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
df['last_price'].describe()
# Out:
# count       23565.000
# mean      6540058.260
# std      10910934.722
# min         12190.000
# 25%       3400000.000
# 50%       4646000.000
# 75%       6790000.000
# max     763000000.000
# Name: last_price, dtype: float64

# %% [markdown]
# Очень странная минимальная цена. посмотрим что это за квартиры:

# %%
df['last_price'].sort_values()
# Out:
# 8793         12190
# 17456       430000
# 14911       430000
# 16274       440000
# 9581        450000
#            ...
# 15651    300000000
# 1436     330000000
# 14706    401300000
# 19540    420000000
# 12971    763000000
# Name: last_price, Length: 23565, dtype: int64

# %%
df.loc[8792]
# Out:
# total_images                              1
# last_price                          7000000
# total_area                           80.000
# first_day_exposition    2019-01-24 00:00:00
# rooms                                     3
# ceiling_height                        2.700
# floors_total                             25
# living_area                          49.000
# floor                                     6
# is_apartment                            NaN
# studio                                False
# open_plan                             False
# kitchen_area                         13.000
# balcony                                   0
# locality_name               Санкт-Петербург
# airports_nearest                  37006.000
# city_center_nearest               15157.000
# parks_around_3000                         0
# parks_nearest                           NaN
# ponds_around_3000                         0
# ponds_nearest                           NaN
# ...

# %% [markdown]
# Cкорее всего это опечатка и на самом деле стоимость квартиры 12 млн. Заменим данные:

# %%
df.loc[8793, 'last_price'] = 12190000

# %%
df.loc[8793][1]
# Out:
# 12190000

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Изменили названия cityCenters_nearest, parks_around3000, ponds_around3000 на, соответственно: city_сenter_nearest, parks_around_3000, ponds_around_3000
# - Отбросили данные с незначительным кол-вом пропусков: locality_name, floors_total
# - Заменим пропуски в days_exposition на 0 и изменили тип данных на int
# - Нулевых значений в living_area и kitchen_area нет, поэтому для удобства заменили Nan на 0
# - В колонках city_center_nearest и airports_nearest сгруппировали по населенному пункту и расстоянию до центра, а потом заменили пропуски на медианные значения
# - Средняя высота и медианна почти не отличаются. Для заполение пустых можно принять любую из них, поэтому заменили пропуски на среднее значение
# - У всех квартир где 0 комнат и не-студий указана living_area. Соответственно, хотя бы 1 комната там есть, поэтому поменяели 0 на 1
# - Заменили пропуски в balcony на 0 (скорее всего балконов в этих помещениях просто нет)
# - Заменили в is_apartment nan на False и перевели в тип bool
# - Оставили parks_nearest и ponds_nearest без изменений, чтобы не искажать результат, так как пропуски составляют больше 60%. А вот в колонках parks_around_3000 и ponds_around_3000 заменим пропуски на средние значения, так как это не сильно отразится на результате

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Поссчитаем цену кваратного метра (для удобства просмотра приведем к типу int):

# %%
df['price_square_m'] = (df['last_price']/df['total_area']).astype(int)

# %% [markdown]
# Создадим столбцы: день недели, месяц и год

# %%
df['weekday_exposition'] = df['first_day_exposition'].dt.weekday
df['month_exposition'] = df['first_day_exposition'].dt.month
df['year_exposition'] = df['first_day_exposition'].dt.year

# %% [markdown]
# Добавим этаж квартиры (варианты — первый, последний, другой):

# %%
def floor_cat (row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    elif 1 < row['floor'] < row['floors_total']:
        return 'другой'

# %%
df['floor_category'] = df.apply(floor_cat, axis = 1)

# %% [markdown]
# Ну и добавим соотношение жилой и общей площади, а также отношение площади кухни к общей:

# %%
df['area_conversion'] = df['living_area'] / df['total_area']

# %%
df['kitchen_conversion'] = df['kitchen_area'] / df['total_area']

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000     108.000           2019-03-07      3
# 1             7     3350000      40.400           2018-12-04      1
# 2            10     5196000      56.000           2015-08-20      2
# 3             0    64900000     159.000           2015-07-24      3
# 4             2    10000000     100.000           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0           2.700            16       51.000      8          NaN   False
# 1           2.700            11       18.600      1          NaN   False
# 2           2.700             5       34.300      4          NaN   False
# 3           2.700            14        0.000      9          NaN   False
# 4           3.000            14       32.000     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# #### Вывод

# %% [markdown]
# - Поссчитали цену кваратного метра, для удобства просмотра привели к типу int
# - Добавили этаж квартиры. Варианты: первый, последний, другой
# - Добавили соотношение жилой и общей площади, а также отношение площади кухни к общей

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра

# %% [markdown]
# Рассмотрим площадь квартир:

# %%
df['total_area'].describe()
# Out:
# count   23565.000
# mean       60.323
# std        35.657
# min        12.000
# 25%        40.000
# 50%        52.000
# 75%        69.700
# max       900.000
# Name: total_area, dtype: float64

# %%
df.plot( y= 'total_area', bins=100, grid= True, kind = 'hist', range =(0, 400))
plt.title('Площадь квартир')
plt.show()

# %% [markdown]
# Распределение данных нормальное. Чаще всего покупают квартиры площадью 45-49 кв.м

# %% [markdown]
# Теперь посмотрим цену:

# %%
df['last_price'].describe()
# Out:
# count       23565.000
# mean      6540575.035
# std      10910913.918
# min        430000.000
# 25%       3400000.000
# 50%       4647000.000
# 75%       6790000.000
# max     763000000.000
# Name: last_price, dtype: float64

# %%
df.plot(y='last_price',kind='hist', grid=True, range=(0, 70000000), bins=30)
plt.title('Цена')
plt.show()

# %% [markdown]
# Из гистораммы видно, что больше всего квартир продается за 4-5 млн. руб

# %% [markdown]
# Посмотрим число комнат:

# %%
df['rooms'].describe()
# Out:
# count   23565.000
# mean        2.073
# std         1.075
# min         0.000
# 25%         1.000
# 50%         2.000
# 75%         3.000
# max        19.000
# Name: rooms, dtype: float64

# %%
df.plot(y='rooms', grid=True, range=(0,8),kind='hist', bins = 30)
plt.title('Число комнат')
plt.show()

# %% [markdown]
# Лучше всего продаются 1 и 2 комнатные квартиры.

# %% [markdown]
# Изучим высоту потолков:

# %%
df['ceiling_height'].describe()
# Out:
# count   23565.000
# mean        2.720
# std         0.219
# min         2.500
# 25%         2.600
# 50%         2.700
# 75%         2.700
# max         5.000
# Name: ceiling_height, dtype: float64

# %%
df.plot(y='ceiling_height',kind='hist', grid=True, range=(2, 5), bins=15)
plt.title('Высота потолков')
plt.show()

# %% [markdown]
# Лучше всего продаются квартиры с полотками 2.6-2.7 м

# %% [markdown]
# #### Вывод

# %% [markdown]
# Лучше всего продаются:
# - 1 и 2 комнатные квартиры
# - стоимостью 4-5 млн. руб
# - с полотками 2.6-2.7 м

# %% [markdown]
# ### Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
df.plot(y='days_exposition', grid=True, bins=20,kind='hist', range=(0,1400), xlim = 0, color='g')
plt.title('Время продажи квартиры')
plt.show()

# %% [markdown]
# Из гистрограммы видно, что пик продаж приходится на значения до 50 дней.
# Некоторые квартиры продавались почти сразу же - значения начинаются от нуля.
# Рассмотрим ближе диапазон 0-300 дней:

# %%
df.plot(y='days_exposition', grid=True, bins=10, range=(0,300),xlim = 0, kind='hist')
plt.title('Время продажи квартиры')
plt.show()

# %% [markdown]
# Наибольшее число квартир проданы в первые 25 дней. После 80 дня продажи резко снижаются

# %%
df.plot(y='days_exposition',kind='hist', grid=True, bins=20, xlim = 0, range=(0,1000), color ='r')
plt.title('Время продажи квартиры')
plt.show()

# %%
cols = ["days_exposition", "last_price", "ceiling_height"]

for col in cols:
    df[col].hist()
    plt.title(col)
    plt.show()

# %% [markdown]
# Хуже всего квартиры продаются после 600 дня продаж

# %%
df['days_exposition'].describe()
# Out:
# count   23565.000
# mean      156.420
# std       213.517
# min         0.000
# 25%        22.000
# 50%        73.000
# 75%       198.000
# max      1580.000
# Name: days_exposition, dtype: float64

# %% [markdown]
# #### Вывод

# %% [markdown]
# - Из гистрограммы видно, что пик продаж приходится на первые 1,5 месяца продаж. Наибольшее число квартир проданы в первый месяц
# - Хуже всего квартиры продаются после 1,5 лет продаж.
# - Среднее значение 5 месяцев (156 дней)
# - Медианное - 2.5 месяцев (73 дня)

# %% [markdown]
# ### Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили

# %%
df['last_price'].describe()
# Out:
# count       23565.000
# mean      6540575.035
# std      10910913.918
# min        430000.000
# 25%       3400000.000
# 50%       4647000.000
# 75%       6790000.000
# max     763000000.000
# Name: last_price, dtype: float64

# %% [markdown]
# Построим диаграмму размаха для столбца last_plrice (примерним пределы) в 430 тыс и 70 млн руб:

# %%
plt.ylim(430000,70000000)
df.boxplot('last_price')

# %% [markdown]
# Как видно из данного графика, выбросы начинаются после 12 млн руб. Посмотрим, сколько всего таких значений есть в первичном датасете:

# %%
len(df.query('last_price > 12000000'))
# Out:
# 1927

# %% [markdown]
# Получили практически 10% данных. Нужно лучше рассмотреть выбросы и понять, какие же значения лучше выделить для менее радикального изменения общих данных.

# %%
plt.ylim(10000000,70000000)
df.boxplot('last_price')

# %% [markdown]
# Плотность выбросов сильно редеет после отметки в 40 млн руб. Проверим, сколько таких значений присутствует в датасете:

# %%
len(df.query('last_price > 40000000'))
# Out:
# 181

# %% [markdown]
# Вот 181 значения уже можно практически безопасно откинуть и не потерять в анализе:

# %%
df_filt = df.query('last_price <= 40000000')
len(df_filt)
# Out:
# 23384

# %% [markdown]
# Рассмотрим время объявления на сайте:

# %%
df_filt['days_exposition'].describe()
# Out:
# count   23384.000
# mean      155.647
# std       212.644
# min         0.000
# 25%        22.000
# 50%        73.000
# 75%       197.000
# max      1580.000
# Name: days_exposition, dtype: float64

# %%
df_filt.boxplot('days_exposition')

# %%
len(df.query('days_exposition > 400'))
# Out:
# 2619

# %% [markdown]
# Снова выбросов больше 10% исходных данных. Посмотрим на данные в более крупном масштабе.
# Интересная особенность: большинство квартир продаются в диапазоне до 200 дней(6,5 мес). Получается, в среднем, продать квартиру можно менее, чем за 7 месяцев:

# %%
plt.ylim(1100, 1600)
df_filt.boxplot('days_exposition')

# %% [markdown]
# Толщина выбросов сильно редеет после отметки в 1250 дней, посмотрим сколько их:

# %%
len(df_filt.query('days_exposition > 1250'))
# Out:
# 67

# %% [markdown]
#  Отбросим из обновленной таблицы эти значения:

# %%
df_filt = df_filt.query('days_exposition < 1250')
len(df_filt)
# Out:
# 23317

# %% [markdown]
# Проверим количество комнат:

# %%
df_filt['rooms'].describe()
# Out:
# count   23317.000
# mean        2.053
# std         1.042
# min         0.000
# 25%         1.000
# 50%         2.000
# 75%         3.000
# max        19.000
# Name: rooms, dtype: float64

# %%
df_filt.boxplot('rooms')

# %%
df_filt = df_filt.query('rooms <= 6')
len(df_filt)
# Out:
# 23251

# %% [markdown]
# Посмотрим площадь:

# %%
df_filt['total_area'].describe()
# Out:
# count   23251.000
# mean       58.366
# std        28.425
# min        12.000
# 25%        40.000
# 50%        51.600
# 75%        68.500
# max       470.300
# Name: total_area, dtype: float64

# %%
df_filt.boxplot('total_area')

# %%
len(df_filt.query('total_area > 110'))
# Out:
# 1108

# %% [markdown]
# График показывает, что выбросы - это все, что имеет площадь более 110 кв.м. Однако, такие обьекты недвижимости - это практически 5% всего обьема данных.

# %%
plt.ylim(150,470)
df_filt.boxplot('total_area')

# %%
len(df_filt.query('total_area > 190'))
# Out:
# 108

# %% [markdown]
# Рассмотрев выбивающиеся значения - принимаем за выбросы площадь более 190 кв.м:

# %%
df_filt = df_filt.query('total_area <= 190').reset_index(drop=True)
len(df_filt)
# Out:
# 23143

# %% [markdown]
# Была произведена очистка таблицы от редких и выбивающихся значений. Удалено примерно 2% из исходных данных.

# %% [markdown]
# #### Вывод

# %% [markdown]
# - В стоблце last_price выбросы начинаются после 12 млн руб, это практически 10% данных. Плотность выбросов сильно редеет после отметки в 40 млн руб, 181 выброс, можно отбросить;
# - В столбце days_exposition снова выбросов больше 10% исходных данных. Интересная особенность: большинство квартир продаются в диапазоне до 200 дней(6,5 мес). Получается, в среднем, продать квартиру можно менее, чем за 7 месяцев. Укрупнив данные, мы выяснили, что толщина выбросов сильно редеет после отметки в 1250 дней, 67 выбросов, можно отбросить;
# - В столбце total_area выбросы - это все, что имеет площадь более 110 кв.м. Однако, такие обьекты недвижимости - это практически 5% всего обьема данных. Рассмотрев выбивающиеся значения - принимаем за выбросы площадь более 190 кв.м.
# - Была произведена очистка таблицы от редких и выбивающихся значений. Удалено примерно 2% из исходных данных

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года

# %% [markdown]
# Рассмотрим зависимость цены от квадратного метра:

# %%
df_filt['last_price'].corr(df_filt['price_square_m'])
# Out:
# 0.7111669468997798

# %%
df_filt.plot(y='last_price', x='price_square_m', kind='scatter', color ='r')
plt.title('Зависимость цены от кв.м')
plt.show()

# %% [markdown]
# Видна очень высокая зависимость цены квартиры от стоимости квадратного метра

# %%
corr_room = df_filt['last_price'].corr(df_filt['rooms'])
corr_room
# Out:
# 0.46974659187918294

# %%
df_filt.plot(y='last_price', x='rooms', kind='scatter', xlim=(0,7))
plt.title('Зависимость цены от количества комнат')
plt.show()

# %% [markdown]
# Как видно, не всегда увеличение количества комнат приводит к увеличению цены. Длинные "жирные" линии в левой половине графика демонстрируют, что за примерно одинаковую цену можно найти 1-2-3 комнатную квартиру. Ведь цена зависит больше от метража и расположения.

# %%
df_filt.plot(y='last_price', x= 'city_center_nearest', kind='scatter')
plt.title('Зависимость цены от расстояния до центра')
plt.show()

# %% [markdown]
# Видна отрицательная корреляция, ведь, чем дальше от центра (увеличение расстояния), тем меньше цена. Но при этом, корреляция не слишком высока. Как видно на графике - дешевые квартиры можно встретить и в центре и на окраине города.
#
# Проверим гипотезу только в Петербурге:

# %%
df_filt_sp = df_filt.query('locality_name == "Санкт-Петербург"')
corr_=df_filt_sp['last_price'].corr(df_filt_sp['city_center_nearest'])

# %%
df_filt_sp.plot(y='last_price', x='city_center_nearest', kind='scatter', color = 'g')
plt.title('Зависимость цены от расстояния до центра. Санкт-Петербург')
plt.show()

# %% [markdown]
# В Санкт-Петербурге данная корреляция не намного, но выше.

# %% [markdown]
# Рассмотрим зависимость от даты размещения (дня недели, месяца и года):

# %%
pivot_weekday = df_filt.pivot_table(index='weekday_exposition', values='last_price', aggfunc=['median', 'mean', 'count'])

# %%
pivot_weekday.columns = [' '.join(col).strip() for col in pivot_weekday.columns.values]
pivot_weekday
# Out:
#                     median last_price  mean last_price  count last_price
# weekday_exposition
# 0                             4600000      5792064.804              3537
# 1                             4700000      5731574.651              4093
# 2                             4650000      5851399.670              3872
# 3                             4600000      5894716.760              4175
# 4                             4500000      5674688.036              3922
# 5                             4500000      5571593.907              1886
# 6                             4500000      5626167.696              1658

# %%
df_filt.pivot_table(index='weekday_exposition', values='last_price', aggfunc='median').plot(grid=True)
plt.title('Зависимость цены от дня недели размещения')
plt.show()

# %% [markdown]
# День недели практически не влияет на цену квартиры. Однако, в субботу и воскресенье размещают практически в 2,5 раза меньше обьявлений. Цены на квартиры в эти дни так же чуть ниже будничных.

# %%
pivot_month = df_filt.pivot_table(index='month_exposition', values='last_price', aggfunc=['median', 'mean', 'count'])

# %%
pivot_month.columns = [' '.join(col).strip() for col in pivot_month.columns.values]
pivot_month
# Out:
#                   median last_price  mean last_price  count last_price
# month_exposition
# 1                           4575000      5845934.679              1457
# 2                           4600000      5770693.006              2583
# 3                           4600000      5713969.622              2534
# 4                           4750000      5788168.968              2319
# 5                           4500000      5791820.753              1236
# 6                           4370000      5580691.559              1718
# 7                           4600000      5698910.913              1647
# 8                           4550000      5809961.897              1717
# 9                           4650000      5837449.463              1938
# 10                          4550000      5666053.403              2081
# 11                          4650000      5882698.111              2323
# 12                          4600000      5724784.813              1590

# %%
df_filt.pivot_table(index='month_exposition', values='last_price', aggfunc='median').plot(grid=True)
plt.title('Зависимость цены от месяца размещения')
plt.show()

# %% [markdown]
# Из графика видно, что в апреле квартиры стоят дороже всего, в июне - дешевле всего (разница по медианным значениям в 300000 руб)

# %%
pivot_year = df_filt.pivot_table(index='year_exposition', values='last_price', aggfunc=['median', 'mean', 'count'])

# %%
pivot_year.columns = [' '.join(col).strip() for col in pivot_year.columns.values]
pivot_year
# Out:
#                  median last_price  mean last_price  count last_price
# year_exposition
# 2014                       6775000      9421909.107               112
# 2015                       5150000      6600030.303              1075
# 2016                       4490000      5780596.271              2692
# 2017                       4490000      5680243.943              8028
# 2018                       4534000      5565486.495              8406
# 2019                       5000000      6080968.008              2830

# %% [markdown]
# Отбросим 2014 год (всего 112 обьявлений в датасете) и построим график изменения средней цены:

# %%
df_filt.query('year_exposition > 2014').pivot_table(index='year_exposition', values='last_price', aggfunc='mean').plot(grid=True)
plt.title('График изменения средней цены')
plt.show()

# %% [markdown]
# Если смотреть по медианным значениям - то 3 года (2016-2018 включительно) медианные цены держались практически на одном уровне. В 2018 году уже заметен рост цен

# %% [markdown]
# Изучим зависимость цены от этажа:

# %%
floor_pivot = df_filt.pivot_table(index='floor_category', values='last_price', aggfunc=['median', 'count'])

# %%
floor_pivot.columns = [' '.join(col).strip() for col in floor_pivot.columns.values]
floor_pivot
# Out:
#                 median last_price  count last_price
# floor_category
# другой                    4800000             17044
# первый                    3900000              2877
# последний                 4250000              3222

# %% [markdown]
# На первом этаже самые дешевые квартиры и меньше всего обьявлений. Нужно еще учитывать и то, что обычно в новостройках первые этажи практически всегда отданы под коммерцию. На последних этажах медианные значения цен выше. Самые дорогие квартиры - на других этажах.

# %% [markdown]
# #### Вывод

# %% [markdown]
# - Видна очень высокая зависимость цены квартиры от стоимости квадратного метра
# - Не всегда увеличение количества комнат приводит к увеличению цены. За примерно одинаковую цену можно найти 1-3 комнатную квартиру. Цена зависит больше от метража и расположения
# - Видна отрицательная корреляция удаленности от центра, ведь, чем дальше от центра (увеличение расстояния), тем меньше цена. Но при этом, корреляция не слишком высока. Как видно на графике - дешевые квартиры можно встретить и в центре и на окраине города. В Санкт-Петербурге данная корреляция не намного, но выше
# - День недели практически не влияет на цену квартиры. В субботу и воскресенье размещают практически в 2,5 раза меньше обьявлений. Цены на квартиры в эти дни так же чуть ниже будничных
# - В апреле квартиры стоят дороже всего, в июне - дешевле всего (разница по медианным значениям в 300000 руб)
# - 3 года (2016-2018 включительно) медианные цены держались практически на одном уровне. В 2018 году уже заметен рост цен
# - На первом этаже самые дешевые квартиры и меньше всего обьявлений. Нужно еще учитывать и то, что обычно в новостройках первые этажи практически всегда отданы под коммерцию. На последних этажах медианные значения цен выше. Самые дорогие квартиры - на других этажах

# %% [markdown]
# ### Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце 'locality_name'.

# %%
df_top_10 = df.groupby('locality_name')['last_price'].agg(['count']).sort_values(by='count',ascending=False).head(10)
df_top_10
# Out:
#                    count
# locality_name
# Санкт-Петербург    15651
# посёлок Мурино       520
# посёлок Шушары       439
# Всеволожск           398
# Пушкин               369
# Колпино              338
# посёлок Парголово    327
# Гатчина              307
# деревня Кудрово      299
# Выборг               237

# %% [markdown]
# Наибольшее количество объявлений в Санкт-Петербурге, наименьшее - в Выборге.

# %%
df_filt.query('locality_name.isin(@df_top_10.index)').pivot_table(index='locality_name', values='price_square_m', aggfunc='median').sort_values(by='price_square_m', ascending=False)
# Out:
#                    price_square_m
# locality_name
# Санкт-Петербург        104424.500
# Пушкин                  99993.500
# деревня Кудрово         91860.000
# посёлок Парголово       91642.000
# посёлок Мурино          85878.000
# посёлок Шушары          76829.000
# Колпино                 74722.000
# Гатчина                 67796.000
# Всеволожск              65789.000
# Выборг                  58158.000

# %% [markdown]
# Самый дорогая стоимость за квадратный метр в Санкт-Петербурге. Самая дешевая - в Выборге.

# %%
df_filt.query('locality_name.isin(@df_top_10.index)').pivot_table(index='locality_name', values='last_price', aggfunc='median').sort_values(by='last_price',ascending=False)
# Out:
#                    last_price
# locality_name
# Санкт-Петербург       5485000
# Пушкин                5150000
# посёлок Парголово     4100000
# посёлок Шушары        3950000
# деревня Кудрово       3790000
# Колпино               3600000
# Всеволожск            3450000
# посёлок Мурино        3400000
# Гатчина               3100000
# Выборг                2897000

# %% [markdown]
# #### Вывод

# %% [markdown]
# Мы выделили топ 10 населённых пунктов с наибольшим числом объявлений.
#
# Среди них:
# - Наибольшее количество объявлений, самая большая стоимость за квадратный метр и самая дорогая стоимость жилья - в Санкт-Петербурге;
# - Наименьшее количество объявлений, самая низкая стоимость за квадртаный метр и самые дешевые квартиры - в Выборге.

# %% [markdown]
# ### Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.

# %% [markdown]
# Выделим квартиры в Санкт-Петербурге, далее выделим строки таблицы, в которую входят значения по Санкт-Петербургу сохраним их в отдельной переменной:

# %%
s_p = df_filt[['locality_name', 'last_price','total_area', 'city_center_nearest', 'city_center_km','rooms', 'ceiling_height', 'floor_category', 'weekday_exposition', 'month_exposition', 'year_exposition']].query('locality_name == "Санкт-Петербург" and total_area > 20').reset_index(drop=True)
s_p.head()
# Out:
#      locality_name  last_price  total_area  city_center_nearest  \
# 0  Санкт-Петербург    13000000     108.000            16028.000
# 1  Санкт-Петербург     5196000      56.000            13933.000
# 2  Санкт-Петербург    10000000     100.000             8098.000
# 3  Санкт-Петербург     7915000      71.600            11634.000
# 4  Санкт-Петербург     5400000      61.000            15008.000
#
#    city_center_km  rooms  ceiling_height floor_category  weekday_exposition  \
# 0              16      3           2.700         другой                   3
# 1              13      2           2.700         другой                   3
# 2               8      2           3.000         другой                   1
# 3              11      2           2.700         другой                   3
# 4              15      3           2.500         другой                   6
#
#    month_exposition  year_exposition
# 0                 3             2019
# 1                 8             2015
# ...

# %%
s_p.pivot_table(index='city_center_km', values='last_price').plot(grid=True, xlim=(0,17))
plt.title('Время продажи квартиры')
plt.show()

# %% [markdown]
# График сильно меняется в двух местах: на 3 км и на 7. Посмотрим данные между 6 и 7 км:

# %%
s_p.query('6<city_center_km<=7').sort_values(by='last_price',ascending=False).head(10)
# Out:
#          locality_name  last_price  total_area  city_center_nearest  \
# 2231   Санкт-Петербург    37272000     100.600             7442.000
# 1960   Санкт-Петербург    37000000     172.000             7302.000
# 10653  Санкт-Петербург    35107000      99.880             7442.000
# 10117  Санкт-Петербург    34551000     103.200             7442.000
# 4537   Санкт-Петербург    32260000     111.900             7442.000
# 14009  Санкт-Петербург    29370000     108.900             7442.000
# 7865   Санкт-Петербург    28000000     100.100             7139.000
# 4118   Санкт-Петербург    27420000     109.200             7442.000
# 1959   Санкт-Петербург    26300000     170.000             7877.000
# 14979  Санкт-Петербург    25900000     167.100             7232.000
#
#        city_center_km  rooms  ceiling_height floor_category  \
# 2231                7      3           2.700      последний
# 1960                7      4           3.000         другой
# ...

# %% [markdown]
# Из таблицы видно, что растущие к 7 км значения цены обусловлены большой площадью продаваемый квартир. Из чего можно сделать вывод, что центральной частью является радиус в 3 км.

# %% [markdown]
# Посчитаем среднюю цену за каждый километр в цетре:

# %%
s_p.query('city_center_km<3').groupby('city_center_km')[['last_price']].mean()
# Out:
#                  last_price
# city_center_km
# 0              12844735.294
# 1              11455692.303
# 2              10942205.109

# %% [markdown]
# #### Вывод

# %% [markdown]
# - В Санкт-Петебурге средняя цена за каждый км в центре:
#   - 12,8 млн за квартиры в пределах 1 км
#   - 11,4 млн за квартиры в пределах 2 км
#   - 11 млн за квартиры в пределах 3 км
# - Центральной частью является радиус в 3 км

# %% [markdown]
# ### Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %% [markdown]
# Создадим таблицу с центральной частью Санкт-Петербурга:

# %%
s_p_center = s_p.query('city_center_km <= 3').reset_index(drop=True)
s_p_center
# Out:
#         locality_name  last_price  total_area  city_center_nearest  \
# 0     Санкт-Петербург     6500000      97.200             2336.000
# 1     Санкт-Петербург    15500000     149.000             3502.000
# 2     Санкт-Петербург     9600000      90.000             2818.000
# 3     Санкт-Петербург     6500000      51.800             3618.000
# 4     Санкт-Петербург     4800000      40.000             2913.000
# ...               ...         ...         ...                  ...
# 1035  Санкт-Петербург     6300000      52.600             3400.000
# 1036  Санкт-Петербург     8500000      65.000             3996.000
# 1037  Санкт-Петербург     8725246      48.200             3539.000
# 1038  Санкт-Петербург     8700000      73.000             2345.000
# 1039  Санкт-Петербург    10100000      78.000             1113.000
#
#       city_center_km  rooms  ceiling_height floor_category  \
# 0                  2      2           2.700         первый
# ...

# %% [markdown]
# Проанализируем площадь, цену, высоту потолков и количество комнат:

# %%
s_p_center.pivot_table(index='locality_name', values=['total_area','last_price','ceiling_height','rooms'], aggfunc='median')
# Out:
#                  ceiling_height  last_price  rooms  total_area
# locality_name
# Санкт-Петербург           3.000     9000000      3      80.000

# %% [markdown]
# В центре выставлены на продажу в среднем трехкомнатные квартиры со средней площадью 80 кв.м, и со средней ценой в 9 млн руб.

# %%
s_p_center.plot(y='total_area', bins=20, kind='hist', grid = True, color ='g')
plt.title('Площадь выставленных квартир. Санкт-Петербург')
plt.show()

# %% [markdown]
# В центре выставлены большинство квартир с площадью 70-100 кв. м.

# %%
df_filt.plot(y='total_area', kind='hist', grid=True, xlim =(0,125), color = 'b')
plt.title('Площадь выставленных квартир')
plt.show()

# %% [markdown]
# Во всём Санкт-Петербурге, в отличие от центра, большинство выставленных квартир площадью 30-50 кв.м.

# %%
s_p_center.plot(y='rooms', grid=True, kind='hist')

# %%
s_p_center.plot(x='last_price', y='rooms', kind='scatter',alpha=0.4, ylim=(0,8))

# %% [markdown]
# В центре города каждая комната прибавляет, примерно, 1 млн руб к общей стоимости, в отличие от города в целом, где корреляция была не такой выраженной

# %%
s_p_center['last_price'].corr(s_p_center['ceiling_height'])
# Out:
# 0.15853969685218816

# %% [markdown]
# Высота потолка не влияет на цену.

# %%
s_p_center['last_price'].corr(s_p_center['total_area'])
# Out:
# 0.616278264600819

# %% [markdown]
# Корелляция 60%. Значит, чем больше площадь квартиры в центре - тем выше её стоимость.

# %%
floor_center_pivot = s_p_center.pivot_table(index='floor_category', values='last_price', aggfunc=['median', 'count'])
floor_center_pivot.columns = [' '.join(col).strip() for col in floor_center_pivot.columns.values]
floor_center_pivot
# Out:
#                 median last_price  count last_price
# floor_category
# другой                    9500000               642
# первый                    6925000               156
# последний                 9000000               242

# %% [markdown]
# Статистка по этажам в центре схожа с общегородской: первый этаж самый дешевый и хуже всего продается. Чаще всего продают и покупают недвижимость жители "других" этажей.

# %%
weekday_center_pivot = s_p_center.pivot_table(index='weekday_exposition', values='last_price', aggfunc=['median', 'mean', 'count'])
weekday_center_pivot.columns = [' '.join(col).strip() for col in weekday_center_pivot.columns.values]
weekday_center_pivot
# Out:
#                     median last_price  mean last_price  count last_price
# weekday_exposition
# 0                             9300000     10877593.665               158
# 1                             9000000     10491852.988               168
# 2                             9600000     11455868.571               175
# 3                             8500000     10946947.930               215
# 4                             9000000     10296958.178               197
# 5                             8250000      9137571.414                70
# 6                             9200000     10808035.088                57

# %% [markdown]
# Cамые дешевые квартиры в центре по субботам! В понедельник и среду самая высокая актиность на рынке.

# %%
s_p_center.pivot_table(index='month_exposition', values='last_price', aggfunc='median').plot()

# %%
s_p_center.pivot_table(index='month_exposition', values='last_price', aggfunc='count').plot()
plt.title('Количество выставленных квартир по месяцам')
plt.show()

# %% [markdown]
# В августе можно найти самые дешевые квартиры в центре, а в сентябре цены резко возрастают. А февраль, ноябрь и март - самые активные месяцы по количеству выставленных на продажу квартир, но в мае-июне квартиры продаются плохо. Данные похожи на общие данные по Санкт-Петербургу.

# %%
year_center_pivot = s_p_center.pivot_table(index='year_exposition', values='last_price', aggfunc=['median', 'mean', 'count'])
year_center_pivot.columns = [' '.join(col).strip() for col in year_center_pivot.columns.values]
year_center_pivot
# Out:
#                  median last_price  mean last_price  count last_price
# year_exposition
# 2014                      16200000     16790000.000                 5
# 2015                       9800000     11818308.511                94
# 2016                       9500000     10363558.000               138
# 2017                       8500000     10259792.838               377
# 2018                       9200000     10649126.891               313
# 2019                       9900000     11483982.699               113

# %% [markdown]
# По годам тоже очень похоже на ситуацию в Санкт-Петербурге в целом.
# При этом, в 2017 году было больше предложений по продаже, возможно это связано с тем, что многим нужны были наличные деньги (в 2016 году был кризис).

# %% [markdown]
# #### Вывод

# %% [markdown]
# Санкт-Петербург:
# - В центре выставлены на продажу в среднем трехкомнатные квартиры с площадью 70-100 кв. м. и со средней ценой в 9 млн руб
# - Во всём Санкт-Петербурге, в отличие от центра, большинство выставленных квартир площадью 30-50 кв.м.
# - Cамые дешевые квартиры в центре по субботам! В понедельник и среду самая высокая актиность на рынке.
# - Статистка по этажам в центре схожа с общегородской: первый этаж самый дешевый и хуже всего продается. Чаще всего продают и покупают недвижимость жители "других" этажей
# - В августе можно найти самые дешевые квартиры в центре, а в сентябре цены резко возрастают. А февраль, ноябрь и март - самые активные месяцы по количеству выставленных на продажу квартир, но в мае-июне квартиры продаются плохо. Данные похожи на общие данные по Санкт-Петербургу
# - Чем больше площадь квартиры в центре - тем выше её стоимость
# - Высота потолка не влияет на цену
# - В центре города каждая комната прибавляет, примерно, 1 млн руб к общей стоимости, в отличие от города в целом, где корреляция была не такой выраженной

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# - Лучше всего продаются:
#   - 1 и 2 комнатные квартиры
#   - стоимостью 4-5 млн. руб
#   - с полотками 2.6-2.7 м
# - Большинство квартир продаются в диапазоне до 200 дней(6,5 мес). Получается, в среднем, продать квартиру можно менее, чем за 7 месяцев.
# - Была произведена очистка таблицы от редких и выбивающихся значений. Удалено примерно 2% из исходных данных
# - Видна очень высокая зависимость цены квартиры от стоимости квадратного метра
# - Не всегда увеличение количества комнат приводит к увеличению цены. За примерно одинаковую цену можно найти 1-3 комнатную квартиру. Цена зависит больше от метража и расположения
# - Видна отрицательная корреляция удаленности от центра, ведь, чем дальше от центра (увеличение расстояния), тем меньше цена. Но при этом, корреляция не слишком высока. Как видно на графике - дешевые квартиры можно встретить и в центре и на окраине города. В Санкт-Петербурге данная корреляция не намного, но выше
# - День недели практически не влияет на цену квартиры. В субботу и воскресенье размещают практически в 2,5 раза меньше обьявлений. Цены на квартиры в эти дни так же чуть ниже будничных
# - В апреле квартиры стоят дороже всего, в июне - дешевле всего (разница по медианным значениям в 300000 руб)
# - 3 года (2016-2018 включительно) медианные цены держались практически на одном уровне. В 2018 году уже заметен рост цен
# - На первом этаже самые дешевые квартиры и меньше всего обьявлений. Нужно еще учитывать и то, что обычно в новостройках первые этажи практически всегда отданы под коммерцию. На последних этажах медианные значения цен выше. Самые дорогие квартиры - на других этажах
# - Были выделены топ 10 населённых пунктов с наибольшим числом объявлений. Среди них:
#   - наибольшее количество объявлений, самая большая стоимость за квадратный метр и самая дорогая стоимость жилья - в Санкт-Петербурге
#   - наименьшее количество объявлений, самая низкая стоимость за квадртаный метр и самые дешевые квартиры - в Выборге.
# - В Санкт-Петебурге:
#   - средняя цена за каждый км = 617684 р
#   - центральной частью является радиус в 3 км
#   - В центре выставлены на продажу в среднем трехкомнатные квартиры с площадью 70-100 кв. м. и со средней ценой в 9 млн руб. Во всём Санкт-Петербурге, в отличие от центра, большинство выставленных квартир - площадью 30-50 кв.м.
#   - Cамые дешевые квартиры выставлены на продажу в центре по субботам! В понедельник и среду самая высокая актиность на рынке.
#   - Статистка по этажам в центре схожа с общегородской: первый этаж самый дешевый и хуже всего продается. Чаще всего продают и покупают недвижимость жители "других" этажей
#   - В августе можно найти самые дешевые квартиры в центре, а в сентябре цены резко возрастают. Февраль, ноябрь и март - самые активные месяцы по количеству выставленных на продажу квартир, но в мае-июне квартиры продаются плохо. Данные похожи на общие данные по Санкт-Петербургу
#   - Чем больше площадь квартиры в центре - тем выше её стоимость
#   - Высота потолка не влияет на цену
#   - В центре города каждая комната прибавляет, примерно, 1 млн руб к общей стоимости, в отличие от города в целом, где корреляция была не такой выраженной
